# %% [markdown]
# ## Load MNIST data & Start TensorFlow session

# %% [markdown]
# ![0.PNG](attachment:0.PNG)

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# ## Building a softmax regression model

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# <img style="float: left;" src="3.PNG">

# %% [markdown]
# <img style="float: left;" src="4.PNG">

# %% [markdown]
# ## Train the model

# %% [markdown]
# <img style="float: left;" src="5.PNG">

# %% [markdown]
# ## Evaluate the model

# %% [markdown]
# <img style="float: left;" src="6.PNG">
